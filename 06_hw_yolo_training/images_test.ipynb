# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

model = YOLO('runs/detect/circle_square_exp/weights/best.pt')
results = model('shapes1.jpg')
annotated = results[0].plot()
plt.imshow(annotated)
plt.show()
# Out:
# image 1/1 /home/edward/Python/Java62/python-ai-62/06_hw_yolo_training/shapes1.jpg: 256x224 1 circle, 8 squares, 29.0ms
# Speed: 0.6ms preprocess, 29.0ms inference, 6.3ms postprocess per image at shape (1, 3, 256, 224)
