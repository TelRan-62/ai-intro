# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

model = YOLO('runs/detect/circle_exp/weights/best.pt')
results = model('datasets/images/val/img13.jpg')
annotated = results[0].plot()
plt.imshow(annotated)
plt.show()
# Out:
# image 1/1 /home/edward/Python/Java62/python-ai-62/06_yolo_training/datasets/images/val/img13.jpg: 256x256 1 circle, 3.9ms
# Speed: 0.6ms preprocess, 3.9ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 256)
