# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

model = YOLO('runs/detect/circle_exp/weights/best.pt')
results = model('datasets/images/val/img1.jpg')
annotated = results[0].plot()
plt.imshow(annotated)
plt.show()
# Out:
# image 1/1 /home/edward/Python/Java62/python-ai-62/06_yolo_training/datasets/images/val/img1.jpg: 256x256 (no detections), 18.4ms
# Speed: 0.3ms preprocess, 18.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
